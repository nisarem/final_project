# %%
import gzip
import pandas as pd
import pickle
import requests
import urllib.parse
import random
import time
from datetime import datetime
import numpy as np

# %%
f = open("token_TMDB.txt","r")
token = f.read()
headers = {"accept": "application/json", "Authorization": f"Bearer {token}"}

# %%
def url_title_tmdb(row, col):
    urls = []
    if pd.isnull(row[col]):
        title = row['originalTitle']
        # Percent encode the title
        title_encoded = urllib.parse.quote(title, safe='')
        url = f"https://api.themoviedb.org/3/search/movie?query={title_encoded}&include_adult=false&language=en-US&page=1"
        urls.append(url)
    return urls

# %%
# file_paths = ['name.basics.tsv.gz',
#               'title.basics.tsv.gz',
#               'title.crew.tsv.gz',
#               'title.ratings.tsv.gz']

# %%
# for item in file_paths:

#     file_name = item[:-7]  # Remove the '.tsv.gz' part
#     print(file_name)
    
#     # Open the gzip-compressed TSV file and read it as a DataFrame
#     with gzip.open(item, 'rt', encoding='utf-8') as f:
#         df = pd.read_table(f, sep='\t', low_memory=False, na_values=["\\N", "nan"])

#     # Save the DataFrame as a pickle file
#     with open(file_name + '.pkl', 'wb') as f:
#         pickle.dump(df, f)

# %%
# ratings = pd.merge(ratings, movies[['tconst']], on='tconst', how='inner')
# ratings = ratings[ratings['tconst'].isin(movies['tconst'])]
# with open('title.ratings.filtered.pkl', 'wb') as f:
#           pickle.dump(ratings, f)

# %%
# crew = pd.merge(crew, movies[['tconst']], on='tconst', how='inner')
# crew = crew[crew['tconst'].isin(movies['tconst'])]
# with open('title.crew.filtered.pkl', 'wb') as f:
#           pickle.dump(crew, f)

# %%
people = pickle.load(open('name.basics.filtered.pkl', 'rb'))
crew = pickle.load(open('title.crew.filtered.pkl', 'rb'))
ratings = pickle.load(open('title.ratings.filtered.pkl', 'rb'))

# %%
movies = pickle.load(open('title.basics.pkl', 'rb'))
movies = movies[movies['titleType']== 'movie']

# %%
movies.drop(columns=['titleType','endYear'], inplace=True)

# %%
movies.isna().all(axis=1).any()
# Out:
# False

# %%
movies.isna().sum()
# Out:
# tconst                 0
# primaryTitle           2
# originalTitle          2
# isAdult                0
# startYear          97185
# runtimeMinutes    249860
# genres             74468
# dtype: int64

# %%
movies.loc[movies['primaryTitle'].isna(), 'primaryTitle'] = 'None'
movies.loc[movies['originalTitle'].isna(), 'originalTitle'] = 'None'

# %%
movies.loc[movies['startYear'].isna()]
# Out:
#              tconst                primaryTitle  \
# 90963     tt0093025  Tales of the Brothers Quay
# 97840     tt0100084                 One Man War
# 109071    tt0111597             The Veiled Hope
# 115754    tt0118530                          18
# 117942    tt0120892               Winding Stair
# ...             ...                         ...
# 10605989  tt9916100       Inventing Robert Capa
# 10606004  tt9916134        The Thing in the Bag
# 10606025  tt9916178          Yesterday's Dreams
# 10606029  tt9916188                    Minotaur
# 10606238  tt9916620           The Copeland Case
#
#                            originalTitle  isAdult  startYear runtimeMinutes  \
# 90963     The Films of the Brothers Quay      0.0        NaN             78
# 97840                   Macon County War      0.0        NaN             92
# 109071                   The Veiled Hope      0.0        NaN             52
# 115754                                18      0.0        NaN            NaN
# 117942                     Winding Stair      0.0        NaN            NaN
# ...                                  ...      ...        ...            ...
# 10605989           Inventing Robert Capa      0.0        NaN            NaN
# 10606004            The Thing in the Bag      0.0        NaN             78
# 10606025              Yesterday's Dreams      0.0        NaN            NaN
# 10606029                        Minotaur      0.0        NaN            NaN
# 10606238               The Copeland Case      0.0        NaN            NaN
#
#                          genres
# 90963     Animation,Documentary
# 97840              Action,Drama
# 109071              Documentary
# 115754                  Romance
# 117942                 Thriller
# ...                         ...
# 10605989    Biography,Drama,War
# 10606004                    NaN
# 10606025                    NaN
# 10606029               Thriller
# 10606238                  Drama
#
# [97185 rows x 7 columns]

# %%
def get_movie_details(url, headers):
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  
        details = response.json()
        return details      
    except requests.exceptions.RequestException as e:
        print(f"Error occurred: {e}")
        return None

# %%
def fill_missing_start_year(df, headers):
    for index, row in df.iterrows():
        imdb_id = row['tconst']
        url = f"https://api.themoviedb.org/3/find/{imdb_id}?external_source=imdb_id"
        print(url)
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()  
            details = response.json()
            movie_results = details.get('movie_results', [])
            if movie_results:
                release_date = movie_results[0].get('release_date')
                if release_date:
                    print(f"Release date for movie {row['originalTitle']}: {release_date}")
                    df.at[index, 'startYear'] = datetime.strptime(release_date, '%Y-%m-%d').year
                    print(f"Updated startYear for: {row['originalTitle']} as {datetime.strptime(release_date, '%Y-%m-%d').year}")
                else:
                    print(f"No release date found for movie: {row['originalTitle']}")
            else:
                print(f"No movie details found for movie: {row['originalTitle']}")
        except requests.exceptions.RequestException as e:
            print(f"Error occurred: {e}")
    
        delay = (random.randint(0,500)/1000)  
        time.sleep(delay)
        print(f"Waiting {delay} seconds...")

# %%
# Select rows from 'movies' DataFrame where 'startYear' is NaN and 
# where the number of NaN values is less than 3
# deneme = movies.loc[movies['startYear'].isna() & (movies.isnull().sum(axis=1) < 3)]
# deneme = fill_missing_start_year(deneme, headers)
# deneme.to_csv('deneme.csv', index=False)

# %%
deneme = pd.read_csv('deneme.csv')

# %%
movies = movies[~movies['tconst'].isin(deneme['tconst'])]
movies = pd.concat([movies, deneme], ignore_index=False)

# %%
movies = pd.merge(crew, movies, on='tconst', how='right')
movies = pd.merge(ratings, movies, on='tconst', how='right')

# %%
def fill_missing_data(df, headers):
    for index, row in df.iterrows():
        imdb_id = row['tconst']
        url = f"https://api.themoviedb.org/3/find/{imdb_id}?external_source=imdb_id"
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()  
            details = response.json()
            movie_results = details.get('movie_results', [])
            
            if movie_results:
                tmdb_id = movie_results[0]['id']
                api_url = f"https://api.themoviedb.org/3/movie/{tmdb_id}?language=en-US"
                
                try:
                    response2 = requests.get(api_url, headers=headers)
                    response2.raise_for_status()
                    data = response2.json()
                    
                    if df.at[index, 'tconst'] == data['imdb_id']:
                        df.at[index, 'averageRating'] = data['vote_average']
                        df.at[index, 'numVotes'] = data['vote_count']
                        df.at[index, 'primaryTitle'] = data['title']
                        df.at[index, 'originalTitle'] = data['original_title']
                        df.at[index, 'runtimeMinutes'] = data['runtime']
                        df.at[index, 'isAdult'] = data['adult']
                        if 'release_date' in data and data['release_date']:
                            df.at[index, 'startYear'] = int(data['release_date'].split('-')[0])
                        if 'genres' in data and data['genres']:
                            genres_set = set(genre['name'] for genre in data['genres'])
                            df.at[index, 'genres'] = genres_set
                        print(f'Data added for {tmdb_id}')
                except Exception as e:
                    print(f"Error processing URL {api_url}: {e}")
            else:
                df = df[df.index != index]

        except requests.exceptions.RequestException as e:
            print(f"Error occurred: {e}")
                
        time.sleep(0.02)
    return df

# %%
cols_to_check = movies.columns.difference(['primaryTitle', 'originalTitle', 'tconst', 'isAdult'])
# result = movies[movies[cols_to_check].isna().all(axis=1)]
# result = fill_missing_data(result, headers)
# result.to_csv('result.csv', index=False)

# %%
result = pd.read_csv('result.csv')

# %%
movies = movies[~movies['tconst'].isin(result['tconst'])]
movies = pd.concat([movies,result], ignore_index=False)

# %%
movies.dropna(subset=cols_to_check, how='all', inplace=True)

# %%
movies.loc[movies['numVotes'] == 0.0, 'numVotes'] = np.nan

# %%
movies.dropna(subset=['numVotes'], inplace=True)

# %%
movies.drop(columns='genres',axis=1).duplicated().any()
# Out:
# False

# %%
# a = movies[movies['tconst']=='tt1375666']
# a['runtimeMinutes'] = None
# a = fill_runtime_data(a, headers)
# a

# %%
# def fill_runtime_data(df, headers):
#     for index, row in df.iterrows():
#         imdb_id = row['tconst']
#         url = f"https://api.themoviedb.org/3/find/{imdb_id}?external_source=imdb_id"
#         try:
#             response = requests.get(url, headers=headers)
#             response.raise_for_status()  
#             details = response.json()
#             movie_results = details.get('movie_results', [])
            
#             if movie_results:
#                 tmdb_id = movie_results[0]['id']
#                 api_url = f"https://api.themoviedb.org/3/movie/{tmdb_id}?language=en-US"
                
#                 try:
#                     response2 = requests.get(api_url, headers=headers)
#                     response2.raise_for_status()
#                     data = response2.json()
                    
#                     if df.at[index, 'tconst'] == data.get('imdb_id', '') and data.get('runtime'):
#                         df.at[index, 'runtimeMinutes'] = str(data['runtime'])
#                         print(f'Data added for {tmdb_id}')
#                         print(df.at[index, 'runtimeMinutes'])
#                 except Exception as e:
#                     print(f"Error processing URL {api_url}: {e}")
#             else:
#                 df = df[df.index != index]
#                 print('deleting row')

#         except requests.exceptions.RequestException as e:
#             print(f"Error occurred: {e}")
                
#         time.sleep(1/50)
#     return df

# %%
# runtime = movies[movies['runtimeMinutes'].isna()]
# runtime = fill_runtime_data(runtime, headers)

# %%
# def get_director_writer(df, headers):
#     for index, row in df.iterrows():
#         imdb_id = row['tconst']
#         url = f"https://api.themoviedb.org/3/find/{imdb_id}?external_source=imdb_id"
#         try:
#             response = requests.get(url, headers=headers)
#             response.raise_for_status()  
#             details = response.json()
#             movie_results = details.get('movie_results', [])
            
#             if movie_results:
#                 tmdb_id = movie_results[0]['id']
#                 api_url = f"https://api.themoviedb.org/3/movie/{tmdb_id}?append_to_response=keywords,credits"
                
#                 try:
#                     response2 = requests.get(api_url, headers=headers)
#                     response2.raise_for_status()
#                     data = response2.json()
                    
#                     if df.at[index, 'tconst'] == data.get('imdb_id', '') and data.get('credits'):
#                         df.at[index, 'directors'] = find_directors(data['credits']['crew'])
#                         df.at[index, 'writers'] = find_writers(data['credits']['crew'])
#                         print(f'Data added for {tmdb_id}')
#                         print(df.at[index, 'directors'])
#                 except Exception as e:
#                     print(f"Error processing URL {api_url}: {e}")
#             else:
#                 df = df[df.index != index]
#                 print('deleting row')

#         except requests.exceptions.RequestException as e:
#             print(f"Error occurred: {e}")
                
#         time.sleep(1/50)
#     return df

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 runtime = pd.read_csv('runtime.csv')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runtime.csv'

# %%
# movies = movies[~movies['tconst'].isin(runtime['tconst'])]
# movies = pd.concat([movies,runtime], ignore_index=False)

# %%
movies.dropna(subset=['runtimeMinutes'], inplace=True)

# %%
# def find_directors(crew_list):
#     directors = set()
#     for crew_member in crew_list:
#         if crew_member.get('job') == 'Director':
#             directors.add(crew_member['name'])
#     if not directors:
#         return None
#     else:
#         return directors

# %%
# def find_writers(crew_list):
#     writers = set()
#     for crew_member in crew_list:
#         if crew_member.get('job') == 'Writer':
#             writers.add(crew_member['name'])
#     if not writers:
#         return None
#     else:
#         return writers

# %%
movies[movies.isna().any(axis=1)]
# Out:
#             tconst  averageRating  numVotes   directors  \
# 0        tt0000009            5.3     208.0   nm0085156
# 1        tt0000147            5.2     504.0   nm0714557
# 2        tt0000502            4.1      15.0   nm0063413
# 3        tt0000574            6.0     872.0   nm0846879
# 4        tt0000591            5.5      23.0   nm0141150
# ...            ...            ...       ...         ...
# 672616   tt6745192            5.0      25.0   nm3859710
# 673570   tt9710724            8.4      15.0  nm10447436
# 0        tt0199860           10.0       1.0         NaN
# 2       tt10192300            3.0       1.0         NaN
# 13      tt28752516            1.5       2.0         NaN
#
#                               writers                   primaryTitle  \
# 0                           nm0085156                     Miss Jerry
# 1                                 NaN  The Corbett-Fitzsimmons Fight
# 2       nm0063413,nm0657268,nm0675388                       Bohemios
# 3                           nm0846879    The Story of the Kelly Gang
# 4                           nm0141150               The Prodigal Son
# ...                               ...                            ...
# 672616                      nm3859710                 Cool as Hell 2
# 673570           nm10447436,nm9477428    Bay Lawz: Stick to the Code
# 0                                 NaN       Ninja: The Final Duel II
# 2                                 NaN                  The Sexy Guys
# 13                                NaN              Lif W Irja'a Tani
#
#                         originalTitle  isAdult  startYear runtimeMinutes  \
# 0                          Miss Jerry      0.0     1894.0             45
# 1       The Corbett-Fitzsimmons Fight      0.0     1897.0            100
# 2                            Bohemios      0.0     1905.0            100
# 3         The Story of the Kelly Gang      0.0     1906.0             70
# 4                   L'enfant prodigue      0.0     1907.0             90
# ...                               ...      ...        ...            ...
# 672616                 Cool as Hell 2      0.0     2017.0             90
# 673570    Bay Lawz: Stick to the Code      0.0        NaN            110
# 0                                 忍武者      0.0     1986.0             89
# 2                             最佳男友进化论      0.0     2019.0             90
# 13                      لف وارجع تاني      0.0     2023.0            100
#
#                             genres  endYear
# 0                          Romance      NaN
# 1           Documentary,News,Sport      NaN
# 2                              NaN      NaN
# 3       Action,Adventure,Biography      NaN
# 4                            Drama      NaN
# ...                            ...      ...
# 672616                      Comedy      NaN
# 673570                       Drama      NaN
# 0                       {'Action'}      NaN
# 2                              NaN      NaN
# 13                      {'Comedy'}      NaN
#
# [305867 rows x 12 columns]

# %%
movies
# Out:
#             tconst  averageRating  numVotes   directors  \
# 0        tt0000009            5.3     208.0   nm0085156
# 1        tt0000147            5.2     504.0   nm0714557
# 2        tt0000502            4.1      15.0   nm0063413
# 3        tt0000574            6.0     872.0   nm0846879
# 4        tt0000591            5.5      23.0   nm0141150
# ...            ...            ...       ...         ...
# 672616   tt6745192            5.0      25.0   nm3859710
# 673570   tt9710724            8.4      15.0  nm10447436
# 0        tt0199860           10.0       1.0         NaN
# 2       tt10192300            3.0       1.0         NaN
# 13      tt28752516            1.5       2.0         NaN
#
#                               writers                   primaryTitle  \
# 0                           nm0085156                     Miss Jerry
# 1                                 NaN  The Corbett-Fitzsimmons Fight
# 2       nm0063413,nm0657268,nm0675388                       Bohemios
# 3                           nm0846879    The Story of the Kelly Gang
# 4                           nm0141150               The Prodigal Son
# ...                               ...                            ...
# 672616                      nm3859710                 Cool as Hell 2
# 673570           nm10447436,nm9477428    Bay Lawz: Stick to the Code
# 0                                 NaN       Ninja: The Final Duel II
# 2                                 NaN                  The Sexy Guys
# 13                                NaN              Lif W Irja'a Tani
#
#                         originalTitle  isAdult  startYear runtimeMinutes  \
# 0                          Miss Jerry      0.0     1894.0             45
# 1       The Corbett-Fitzsimmons Fight      0.0     1897.0            100
# 2                            Bohemios      0.0     1905.0            100
# 3         The Story of the Kelly Gang      0.0     1906.0             70
# 4                   L'enfant prodigue      0.0     1907.0             90
# ...                               ...      ...        ...            ...
# 672616                 Cool as Hell 2      0.0     2017.0             90
# 673570    Bay Lawz: Stick to the Code      0.0        NaN            110
# 0                                 忍武者      0.0     1986.0             89
# 2                             最佳男友进化论      0.0     2019.0             90
# 13                      لف وارجع تاني      0.0     2023.0            100
#
#                             genres  endYear
# 0                          Romance      NaN
# 1           Documentary,News,Sport      NaN
# 2                              NaN      NaN
# 3       Action,Adventure,Biography      NaN
# 4                            Drama      NaN
# ...                            ...      ...
# 672616                      Comedy      NaN
# 673570                       Drama      NaN
# 0                       {'Action'}      NaN
# 2                              NaN      NaN
# 13                      {'Comedy'}      NaN
#
# [305867 rows x 12 columns]

# %%
movies.dropna(inplace=True)

# %%
movies['startYear'] = pd.to_datetime(movies['startYear'], format='%Y', errors='coerce').dt.year
movies['runtimeMinutes'] = pd.to_numeric(movies['runtimeMinutes'], errors='coerce').astype('Int64')

# %%
#movies.to_csv('movies.csv',index=False)

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.isna().sum()
# Out:
# tconst                 0
# averageRating          0
# numVotes               0
# directors           3651
# writers            37935
# primaryTitle           0
# originalTitle          0
# isAdult                0
# startYear             23
# runtimeMinutes     30347
# genres              9920
# endYear           305867
# dtype: int64

# %%
def format_set(df, col):
    if not isinstance(df[col].iloc[0], set):
        df[col] = df[col].str.split(',')
        df[col] = df[col].apply(lambda x: set(x) if isinstance(x, list) else set())
    else:
        df[col] = df[col]
    return df

# %%
format_set(movies,'directors')
format_set(movies,'writers')
format_set(movies,'genres')

# %%
#crew2 = pickle.load(open('title.crew.pkl', 'rb'))
#crew2[crew2['tconst'].isin((movies[movies['directors'].isna()]['tconst']).unique())]['directors'].unique()
#so these empty rows where also in crew dataset

# %%
# def fill_missing_data(df, headers):
#     if 'api_url' not in df.columns:
#         df['api_url'] = ''
#     for index, row in df.iterrows():
#         url = url_id_tmdb(row, 'startYear')  # Assuming you have a function url_id_tmdb to construct the URL
#         df.at[index, 'api_url'] = url  # Add the URL to the DataFrame
        
#         try:
#             response = requests.get(url, headers=headers)
#             response.raise_for_status()  
#             details = response.json()
#             movie_results = details.get('movie_results', [])
            
#             if movie_results:
#                 tmdb_id = movie_results[0]['id']
#                 api_url = f"https://api.themoviedb.org/3/movie/{tmdb_id}?language=en-US"
                
#                 try:
#                     response2 = requests.get(api_url, headers=headers)
#                     response2.raise_for_status()
#                     data = response2.json()
                    
#                     if df.at[index, 'tconst'] == data['imdb_id']:
#                         df.at[index, 'averageRating'] = data['vote_average']
#                         df.at[index, 'numVotes'] = data['vote_count']
#                         df.at[index, 'primaryTitle'] = data['title']
#                         df.at[index, 'startYear'] = data['release_date'].split('-')[0]
#                         df.at[index, 'originalTitle'] = data['original_title']
#                         df.at[index, 'isAdult'] = data['adult']
#                         if 'genres' in data:
#                             genres_set = set(genre['name'] for genre in data['genres'])
#                             df.at[index, 'genres'] = genres_set
#                 except Exception as e:
#                     print(f"Error processing URL {api_url}: {e}")
#             else:
#                 print(f"No movie results found for URL {url}")
#                 df.drop(index=index, inplace=True)

#         except requests.exceptions.RequestException as e:
#             print(f"Error occurred: {e}")
                
#         time.sleep(0.05)
#     df.drop(['api_url'],axis=1,inplace=True)
#     return df

# %%
df.isna().sum()

# %%
pd.set_option('display.max_columns', 25)

# %%
new = pd.read_csv('TMDB_movie_dataset.csv')

# %%
cols = ['id','genres','title','overview',
        'popularity','release_date','runtime','vote_average','production_countries','production_companies']

# %%
movies = movies[movies['runtimeMinutes'] > 45]
movies = movies[movies['numVotes'] > 50]
movies = movies[movies['startYear'] > 1900]

# %%
new = new[new['imdb_id'].isin(movies['tconst'])]

# %%
f = open("api_key_OMDb.txt","r")
key = f.read()
url= 'http://www.omdbapi.com/?apikey='+key+'&t=gone+girl'
# Out:
#              id                  title  vote_average  vote_count    status  \
# 0         27205              Inception         8.364       34495  Released
# 1        157336           Interstellar         8.417       32571  Released
# 2           155        The Dark Knight         8.512       30619  Released
# 3         19995                 Avatar         7.573       29815  Released
# 4         24428           The Avengers         7.710       29166  Released
# ...         ...                    ...           ...         ...       ...
# 1006376  666474            Köşe Dönücü         0.000           0  Released
# 1006381  666482    Çanakkale Aslanları         0.000           0  Released
# 1006383  666485  Yasemin'in Tatlı Aşkı         0.000           0  Released
# 1006458  666870          Found Footage         0.000           0  Released
# 1006462  666875             Riki Rhino         0.000           0  Released
#
#         release_date     revenue  runtime  adult  \
# 0         2010-07-15   825532764      148  False
# 1         2014-11-05   701729206      169  False
# 2         2008-07-16  1004558444      152  False
# 3         2009-12-15  2923706026      162  False
# 4         2012-04-25  1518815515      143  False
# ...              ...         ...      ...    ...
# 1006376   1985-01-01           0        0  False
# 1006381   1964-06-02           0        0  False
# 1006383   1968-02-14           0       83  False
# 1006458   2014-10-22           0       93  False
# 1006462   2020-02-27           0       92  False
#
#                             backdrop_path     budget  \
# 0        /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  160000000
# 1        /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  165000000
# 2        /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  185000000
# 3        /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  237000000
# 4        /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  220000000
# ...                                   ...        ...
# 1006376                               NaN          0
# 1006381                               NaN          0
# 1006383                               NaN          0
# 1006458                               NaN        500
# 1006462  /i4Bo9kNkUwdTKsGYk6PZBNMhBXn.jpg          0
#
#                                                homepage     imdb_id  \
# 0           https://www.warnerbros.com/movies/inception   tt1375666
# 1                     http://www.interstellarmovie.net/   tt0816692
# 2        https://www.warnerbros.com/movies/dark-knight/   tt0468569
# 3                  https://www.avatar.com/movies/avatar   tt0499549
# 4            https://www.marvel.com/movies/the-avengers   tt0848228
# ...                                                 ...         ...
# 1006376                                             NaN   tt4250338
# 1006381                                             NaN   tt0290337
# 1006383                                             NaN   tt0348447
# 1006458                                             NaN   tt3469330
# 1006462                                             NaN  tt11710070
#
#         original_language         original_title  \
# 0                      en              Inception
# 1                      en           Interstellar
# 2                      en        The Dark Knight
# 3                      en                 Avatar
# 4                      en           The Avengers
# ...                   ...                    ...
# 1006376                tr            Köşe Dönücü
# 1006381                tr    Çanakkale Aslanları
# 1006383                tr  Yasemin'in Tatlı Aşkı
# 1006458                en          Found Footage
# 1006462                id             Riki Rhino
#
#                                                   overview  popularity  \
# 0        Cobb, a skilled thief who commits corporate es...      83.952
# 1        The adventures of a group of explorers who mak...     140.241
# 2        Batman raises the stakes in his war on crime. ...     130.643
# 3        In the 22nd century, a paraplegic Marine is di...      79.932
# 4        When an unexpected enemy emerges and threatens...      98.082
# ...                                                    ...         ...
# 1006376                                                NaN       0.600
# 1006381                                                NaN       0.600
# 1006383  While the young couple dreams of marriage, the...       0.846
# 1006458  Three teens set out to fix their schools bully...       0.600
# 1006462  Riki, a young Sumatran rhino, lost his horn, w...       0.600
#
#                               poster_path  \
# 0        /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1        /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2        /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3        /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4         /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# ...                                   ...
# 1006376  /f2F3vSGaha42aFRVbKukgQgqzQk.jpg
# 1006381  /x8rcJ5FIDixR4OPQWTPM5XQKerw.jpg
# 1006383  /sBhrwBeCnfQ8YYOhFqNO8iMjOXK.jpg
# 1006458  /oh4zR437EuPrg1Pj1hgkAR2cusF.jpg
# 1006462  /rbxzOoAWI4WYSpoBFCuJFz3El95.jpg
#
#                                                    tagline  \
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1006376                                                NaN
# 1006381                                                NaN
# 1006383                                                NaN
# 1006458                                                NaN
# 1006462                                                NaN
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1006376                                       Comedy
# 1006381                                 War, History
# 1006383                       Comedy, Romance, Music
# 1006458                                       Comedy
# 1006462                         Animation, Adventure
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1006376                                 Bengi Video & Film
# 1006381                And Film, Tsk, tsk, tsk Productions
# 1006383                                         Saner Film
# 1006458                                                NaN
# 1006462                                   Batavia Pictures
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1006376                                    Turkey
# 1006381                                    Turkey
# 1006383                                    Turkey
# 1006458                                       NaN
# 1006462                                 Indonesia
#
#                            spoken_languages
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1006376                             Turkish
# 1006381                                 NaN
# 1006383                             Turkish
# 1006458                                 NaN
# 1006462                          Indonesian
#
# [139519 rows x 23 columns]

# %%
movies = movies[movies['averageRating'] >= 3.7]

# %%
new = new[new['imdb_id'].isin(movies['tconst'])]

# %%
new = new[(new['popularity'] > 1) & (new['status'] == 'Released')]

# %%
new = new.dropna(subset=['overview'])

# %%
new = new.dropna(subset=['genres'])

# %%
new = new.dropna(subset=['production_countries'])

# %%
new = new.drop(columns=['backdrop_path', 'homepage', 'poster_path', 'tagline', 'production_companies'])

# %%
new = new.drop(columns=['spoken_languages'])

# %%
new = new.dropna()

# %%
movies
# Out:
#            tconst  averageRating  numVotes                      directors  \
# 1       tt0000574            6.0     872.0                      nm0846879
# 6       tt0001285            5.4      60.0                      nm0085865
# 16      tt0002101            5.1     615.0                      nm0309130
# 17      tt0002130            7.0    3396.0  nm0078205,nm0655824,nm0209738
# 21      tt0002423            6.6     996.0                      nm0523932
# ...           ...            ...       ...                            ...
# 248322  tt9379530            4.2     147.0                      nm3860913
# 248346  tt9592686            6.5     331.0                      nm8426796
# 248347  tt9593792            4.9     247.0                     nm10316044
# 248363  tt9753314            6.6     593.0                      nm7240066
# 248365  tt9774740            7.1      69.0                      nm1261206
#
#                       writers                 primaryTitle  \
# 1                   nm0846879  The Story of the Kelly Gang
# 6         nm0676645,nm0836316            The Life of Moses
# 16        nm0765026,nm0309130                    Cleopatra
# 17                  nm0019604              Dante's Inferno
# 21        nm0266183,nm0473134                      Passion
# ...                       ...                          ...
# 248322              nm3860913                   Max Bishop
# 248346   nm8426796,nm10395878         Stay Awesome, China!
# 248347  nm10396240,nm10316044                   Ghost Wife
# 248363              nm7240066        The Shepherd's Supper
# 248365    nm3174077,nm1261206              Chasing Whiskey
#
#                       originalTitle  isAdult  startYear  runtimeMinutes  \
# 1       The Story of the Kelly Gang      0.0       1906              70
# 6                 The Life of Moses      0.0       1909              50
# 16                        Cleopatra      0.0       1912             100
# 17                        L'Inferno      0.0       1911              71
# 21                   Madame DuBarry      0.0       1919             113
# ...                             ...      ...        ...             ...
# 248322                   Max Bishop      0.0       2021              84
# 248346         Stay Awesome, China!      0.0       2019              77
# 248347                   Ghost Wife      0.0       2018              99
# 248363        The Shepherd's Supper      0.0       2023             120
# 248365              Chasing Whiskey      0.0       2021              95
#
#                                       genres
# 1       {'Action', 'Biography', 'Adventure'}
# 6           {'Drama', 'Biography', 'Family'}
# 16                      {'History', 'Drama'}
# 17         {'Drama', 'Adventure', 'Fantasy'}
# 21         {'Romance', 'Drama', 'Biography'}
# ...                                      ...
# 248322                   {'Comedy', 'Crime'}
# 248346                       {'Documentary'}
# 248347         {'Drama', 'Horror', 'Comedy'}
# 248363                             {'Drama'}
# 248365                       {'Documentary'}
#
# [94535 rows x 11 columns]

# %%
movies = movies[movies['tconst'].isin(new['imdb_id'])]

# %%
movies = movies[movies['runtimeMinutes'] > 60]
movies = movies[movies['numVotes'] > 100]
movies = movies[movies['startYear'] > 1920]

# %%
movies = movies[movies['isAdult']==0]

# %%
movies
# Out:
#            tconst  averageRating  numVotes            directors  \
# 924     tt0010969            6.7     424.0            nm0275494
# 980     tt0011294            7.2     240.0            nm0031134
# 1013    tt0011440            6.5     248.0            nm0814027
# 1093    tt0011904            6.8    1320.0            nm0941637
# 1095    tt0011908            5.6     167.0  nm0384616,nm0796657
# ...           ...            ...       ...                  ...
# 248309  tt9252316            6.8     238.0            nm3141234
# 248322  tt9379530            4.2     147.0            nm3860913
# 248346  tt9592686            6.5     331.0            nm8426796
# 248347  tt9593792            4.9     247.0           nm10316044
# 248363  tt9753314            6.6     593.0            nm7240066
#
#                                         writers                  primaryTitle  \
# 924                         nm0072315,nm0275494              Missing Husbands
# 980                         nm0173213,nm3561683  The Swallow and the Titmouse
# 1013                        nm0359105,nm0814027                 Markens grøde
# 1093                        nm0606563,nm0927851             The Ace of Hearts
# 1095    nm0123194,nm0384616,nm0884265,nm0257877          Adventures of Tarzan
# ...                                         ...                           ...
# 248309                                nm2085376                Erasing Family
# 248322                                nm3860913                    Max Bishop
# 248346                     nm8426796,nm10395878          Stay Awesome, China!
# 248347                    nm10396240,nm10316044                    Ghost Wife
# 248363                                nm7240066         The Shepherd's Supper
#
#                      originalTitle  isAdult  startYear  runtimeMinutes  \
# 924                    L'Atlantide      0.0       1921             172
# 980     L'hirondelle et la mésange      0.0       1924              80
# 1013                 Markens grøde      0.0       1921             107
# 1093             The Ace of Hearts      0.0       1921              75
# 1095          Adventures of Tarzan      0.0       1921              73
# ...                            ...      ...        ...             ...
# 248309              Erasing Family      0.0       2020              92
# 248322                  Max Bishop      0.0       2021              84
# 248346        Stay Awesome, China!      0.0       2019              77
# 248347                  Ghost Wife      0.0       2018              99
# 248363       The Shepherd's Supper      0.0       2023             120
#
#                                      genres
# 924     {'Fantasy', 'Adventure', 'Mystery'}
# 980                               {'Drama'}
# 1013                              {'Drama'}
# 1093          {'Drama', 'Mystery', 'Crime'}
# 1095                {'Action', 'Adventure'}
# ...                                     ...
# 248309                      {'Documentary'}
# 248322                  {'Comedy', 'Crime'}
# 248346                      {'Documentary'}
# 248347        {'Drama', 'Horror', 'Comedy'}
# 248363                            {'Drama'}
#
# [82797 rows x 11 columns]

# %%
movies[movies['numVotes']>1000]
# Out:
#             tconst  averageRating  numVotes             directors  \
# 1093     tt0011904            6.8    1320.0             nm0941637
# 1096     tt0011909            6.6    1351.0             nm0001124
# 1109     tt0011960            6.9    1298.0             nm0523932
# 1121     tt0012027            6.5    1061.0             nm0806605
# 1148     tt0012190            7.1    3539.0             nm0002271
# ...            ...            ...       ...                   ...
# 246088   tt2075277            7.3    1137.0             nm1680229
# 246328  tt22497964            4.8    1231.0            nm14111507
# 246393  tt23043386            4.2    1220.0  nm0007161,nm11140532
# 247657   tt5748648            4.9    1378.0             nm6490860
# 247898   tt6793470            6.0    1733.0             nm5394449
#
#                      writers                         primaryTitle  \
# 1093     nm0606563,nm0927851                    The Ace of Hearts
# 1096     nm0774217,nm0534221                The Affairs of Anatol
# 1109     nm0473134,nm0523932                          The Wildcat
# 1121     nm0241414,nm0558923                              Camille
# 1148     nm0087658,nm0558923  The Four Horsemen of the Apocalypse
# ...                      ...                                  ...
# 246088  nm1680229,nm12290644                           Paramathma
# 246328            nm14111507                          Gurumoorthi
# 246393             nm0007161           Organic Mama Hybrid Alludu
# 247657             nm1213847                         The Bachelor
# 247898            nm10080143                       Horob Edterary
#
#                               originalTitle  isAdult  startYear  \
# 1093                      The Ace of Hearts      0.0       1921
# 1096                  The Affairs of Anatol      0.0       1921
# 1109                          Die Bergkatze      0.0       1921
# 1121                                Camille      0.0       1921
# 1148    The Four Horsemen of the Apocalypse      0.0       1921
# ...                                     ...      ...        ...
# 246088                           Paramathma      0.0       2011
# 246328                          Gurumoorthi      0.0       2022
# 246393           Organic Mama Hybrid Alludu      0.0       2023
# 247657                         The Bachelor      0.0       2016
# 247898                       Horob Edterary      0.0       2017
#
#         runtimeMinutes                            genres
# 1093                75     {'Drama', 'Mystery', 'Crime'}
# 1096               117               {'Drama', 'Comedy'}
# 1109                79    {'Romance', 'Drama', 'Comedy'}
# 1121                72              {'Romance', 'Drama'}
# 1148               150       {'Romance', 'Drama', 'War'}
# ...                ...                               ...
# 246088             132                       {'Romance'}
# 246328             122            {'Action', 'Thriller'}
# 246393             148                        {'Action'}
# 247657             110             {'Romance', 'Comedy'}
# 247898             120  {'Action', 'Thriller', 'Comedy'}
#
# [37452 rows x 11 columns]

# %%
movies.describe().T
# Out:
#                   count          mean           std     min     25%     50%  \
# averageRating   82797.0      6.085535      1.003987     3.7     5.4     6.2
# numVotes        82797.0  12968.353080  68329.319774   101.0   295.0   806.0
# isAdult         82797.0      0.000000      0.000000     0.0     0.0     0.0
# startYear       82797.0   1994.966110     25.210272  1921.0  1978.0  2004.0
# runtimeMinutes  82797.0    101.633694     28.640072    61.0    89.0    97.0
#
#                    75%        max
# averageRating      6.8        9.5
# numVotes        3143.0  2866728.0
# isAdult            0.0        0.0
# startYear       2015.0     2024.0
# runtimeMinutes   110.0     5220.0

# %%
def update_vote_info(df1, df2):
    for index, row in df1.iterrows():
        imdb_id = row['imdb_id']
        matching_row = df2[df2['tconst'] == imdb_id]
        if not matching_row.empty:
            df1.at[index, 'vote_average'] = matching_row.iloc[0]['averageRating']
            df1.at[index, 'vote_count'] = matching_row.iloc[0]['numVotes']


update_vote_info(new, movies)

# %%
df = pd.merge(new, movies, left_on='imdb_id', right_on='tconst', how='inner')

# %%
df.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'budget', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'genres_x',
#        'production_countries', 'release_year', 'tconst', 'averageRating',
#        'numVotes', 'directors', 'writers', 'primaryTitle', 'originalTitle',
#        'isAdult', 'startYear', 'runtimeMinutes', 'genres_y'],
#       dtype='object')

# %%
#df['runtime'] = df['runtimeMinutes']
df['release_date'] = df['release_year']

# %%
df.drop(columns=['runtimeMinutes','startYear'],inplace=True)

# %%
df.drop(columns=['release_year'],inplace=True)

# %%
# List of columns to drop
cols_to_drop = ['tconst', 'averageRating', 'numVotes', 'directors', 'writers', 'primaryTitle', 'originalTitle', 'isAdult', 'genres_y']

# Drop the specified columns
df.drop(columns=cols_to_drop, inplace=True)

# %%
df['genres_x'].iloc[0]
# Out:
# 'Action, Science Fiction, Adventure'

# %%
df = df[df['vote_count']>1000]

# %%
df.isna().sum()
# Out:
# id                      0
# title                   0
# vote_average            0
# vote_count              0
# status                  0
# release_date            0
# revenue                 0
# runtime                 0
# adult                   0
# budget                  0
# imdb_id                 0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# genres_x                0
# production_countries    0
# dtype: int64

# %%
df.to_csv('final.csv')

# %%
type(df['id'])
# Out:
# pandas.core.series.Series
